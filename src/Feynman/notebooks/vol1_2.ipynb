# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
n=10
t = np.arange(0.01, 20, 0.01)
I = (np.sin(n*t/2)**2)/(np.sin(t/2)**2)

# %%
plt.plot(t, I)

# %%
w=np.arange(1,1.0e13, 1.0e6)
kB = 1.38e-23
hb = 6.62607015e-34
mu = 6.64e-27
Iw = (w**3)/(np.exp(hb*w/(kB*10))-1)
plt.plot(w, Iw)

# %%
len(w)
# Out:
# 1000000
