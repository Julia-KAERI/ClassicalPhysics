# %%
using CairoMakie, NAJ

# %%
f(t) = 3*t^6 - 3*t^4 - 3*t^2 -1
# Out:
# f (generic function with 1 method)

# %%
s = -2:0.01:2
fig = Figure()
ax = Axis(fig[1, 1])
lines!(ax, s, f.(s))
fig

# %%
rootfinding_bisection(f, 1, 2)
# Out:
# (1.304766021668911, 26)
