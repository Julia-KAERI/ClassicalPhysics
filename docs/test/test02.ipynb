# %%
using Plots

# %%
f(x) = 2*(x^2 - 4*x + 3 + 1/x)*exp(-0.2*(x^2))
t=1:0.01:10
plot(t, (f.(t)))

# %%
findmin(f.(t))
# Out:
# (-0.45312206899663027, 95)

# %%
t=0.0:0.01:20*pi

q = ℯ/2.5
x = cos.(t) ./ (1 .+ 0.8 .* cos.(1.08731 .* t) )
y = sin.(t) ./ (1 .+ 0.8 .* cos.(1.08731.* t))
plot(x, y, aspect_ratio = :equal, frame = :none, label = :none)

# %%
ℯ/2.5
# Out:
# 1.087312731383618
