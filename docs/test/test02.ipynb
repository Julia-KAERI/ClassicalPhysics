# %%
using Plots

# %%
f(x) = 2*(x^2 - 4*x + 3 + 1/x)*exp(-0.2*(x^2))
t=1:0.01:10
plot(t, (f.(t)))

# %%
# Out:
# UndefVarError: `plot` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Documents/Projects/ClassicalMechanics.doc/docs/test/test02.ipynb:2
